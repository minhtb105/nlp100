# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv(r'/content/drive/MyDrive/data/popular_names.txt', delimiter='\t', header=None)
df.head()
# Out:
#            0  1     2     3
# 0       Mary  F  7065  1880
# 1       Anna  F  2604  1880
# 2       Emma  F  2003  1880
# 3  Elizabeth  F  1939  1880
# 4     Minnie  F  1746  1880

# %%
# Count the number of lines of the file
len(df)
# Out:
# 2780

# %%
df.replace('\t', ' ', regex=True, inplace=True)

# %%
col1 = df.iloc[0:, 0]
col2 = df.iloc[0:, 1]

col1.to_csv(r'/content/drive/MyDrive/data/col1.txt', index=False, header=False)
col2.to_csv(r'/content/drive/MyDrive/data/col2.txt', index=False, header=False)

# %%
N=10

df.head(N)
# Out:
#            0  1     2     3
# 0       Mary  F  7065  1880
# 1       Anna  F  2604  1880
# 2       Emma  F  2003  1880
# 3  Elizabeth  F  1939  1880
# 4     Minnie  F  1746  1880
# 5   Margaret  F  1578  1880
# 6        Ida  F  1472  1880
# 7      Alice  F  1414  1880
# 8     Bertha  F  1320  1880
# 9      Sarah  F  1288  1880

# %%
df.tail(N)
# Out:
#              0  1      2     3
# 2770      Liam  M  19837  2018
# 2771      Noah  M  18267  2018
# 2772   William  M  14516  2018
# 2773     James  M  13525  2018
# 2774    Oliver  M  13389  2018
# 2775  Benjamin  M  13381  2018
# 2776    Elijah  M  12886  2018
# 2777     Lucas  M  12585  2018
# 2778     Mason  M  12435  2018
# 2779     Logan  M  12352  2018

# %%
import random

N = random.randint(2, 20)
boundaries = list(range(0, len(df), int(len(df) / N)))

result = []
for i in range(len(boundaries) - 1):
  result.append(df.iloc[boundaries[i]:boundaries[i+1], 0:].values)

result
# Out:
# [array([['Mary', 'F', 7065, 1880],
#         ['Anna', 'F', 2604, 1880],
#         ['Emma', 'F', 2003, 1880],
#         ...,
#         ['Helen', 'F', 26884, 1926],
#         ['Margaret', 'F', 23070, 1926],
#         ['Ruth', 'F', 20223, 1926]], dtype=object),
#  array([['Doris', 'F', 16298, 1926],
#         ['Virginia', 'F', 16162, 1926],
#         ['Mildred', 'F', 13551, 1926],
#         ...,
#         ['Nicole', 'F', 15752, 1972],
#         ['Michael', 'M', 71405, 1972],
#         ['Christopher', 'M', 52189, 1972]], dtype=object),
#  array([['James', 'M', 47083, 1972],
#         ['David', 'M', 46366, 1972],
#         ['John', 'M', 43181, 1972],
#         ...,
#         ['Benjamin', 'M', 13381, 2018],
#         ['Elijah', 'M', 12886, 2018],
#         ['Lucas', 'M', 12585, 2018]], dtype=object)]
# [array([['Mary', 'F', 7065, 1880],
#         ['Anna', 'F', 2604, 1880],
#         ['Emma', 'F', 2003, 1880],
#         ...,
#         ['George', 'M', 4445, 1907],
# ...

# %%
df.iloc[0:, 0].unique()
# Out:
# array(['Mary', 'Anna', 'Emma', 'Elizabeth', 'Minnie', 'Margaret', 'Ida',
#        'Alice', 'Bertha', 'Sarah', 'John', 'William', 'James', 'Charles',
#        'George', 'Frank', 'Joseph', 'Thomas', 'Henry', 'Robert', 'Annie',
#        'Edward', 'Clara', 'Florence', 'Ethel', 'Bessie', 'Harry', 'Helen',
#        'Ruth', 'Marie', 'Lillian', 'Mildred', 'Dorothy', 'Frances',
#        'Walter', 'Evelyn', 'Virginia', 'Richard', 'Betty', 'Donald',
#        'Doris', 'Shirley', 'Barbara', 'Patricia', 'Joan', 'Nancy',
#        'Carol', 'David', 'Ronald', 'Judith', 'Linda', 'Sandra', 'Carolyn',
#        'Sharon', 'Michael', 'Susan', 'Donna', 'Larry', 'Kathleen',
#        'Deborah', 'Gary', 'Karen', 'Debra', 'Pamela', 'Cynthia', 'Mark',
#        'Steven', 'Lisa', 'Jeffrey', 'Lori', 'Kimberly', 'Tammy', 'Angela',
#        'Michelle', 'Jennifer', 'Melissa', 'Christopher', 'Brian', 'Amy',
#        'Laura', 'Tracy', 'Julie', 'Jason', 'Scott', 'Stephanie',
# ...

# %%
df_sorted = df.sort_values(by=[2], ascending=False, ignore_index=True)

df_sorted

# df.columns
# Out:
#             0  1      2     3
# 0       Linda  F  99689  1947
# 1       Linda  F  96211  1948
# 2       James  M  94757  1947
# 3     Michael  M  92704  1957
# 4      Robert  M  91640  1947
# ...       ... ..    ...   ...
# 2775    Annie  F   1326  1881
# 2776   Bertha  F   1324  1881
# 2777   Bertha  F   1320  1880
# 2778    Alice  F   1308  1881
# 2779    Sarah  F   1288  1880
#
# [2780 rows x 4 columns]

# %%
freq_first_col = df.iloc[0:, 0].value_counts().sort_values(ascending=False)


freq_first_col
# Out:
# James      118
# William    111
# Robert     108
# John       108
# Mary        92
#           ...
# Scott        1
# Rachel       1
# Kelly        1
# Crystal      1
# Lucas        1
# Name: 0, Length: 136, dtype: int64
